# %%
import sys, pathlib
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.telemetry_loader import TelemetryLoader
#       2 from src.lap import Lap
#       3 from src.lap_analyzer import LapAnalyzer
#
# ModuleNotFoundError: No module named 'src.telemetry_loader'

# %%
PROJECT_ROOT = pathlib.Path(r"~\PycharmProjects\gemini api").expanduser()
sys.path.append(str(PROJECT_ROOT))

hot_lap_file_path = "assets/MoTec/spa/Spa-ferrari_296_gt3-fastest_lap_glat-float.csv"
user_lap_file_path = "assets/MoTec/spa/Spa-ferrari_296_gt3-8-hotlap_2-17-860.csv"

t_loader = TelemetryLoader(base_dir=PROJECT_ROOT / "src")                     # nutzt den absolut gesetzten MOTEC_FOLDER
record_df = t_loader.telemetry_from_csv(hot_lap_file_path, "spa")
user_df = t_loader.telemetry_from_csv(user_lap_file_path, "spa")

print(user_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 PROJECT_ROOT = pathlib.Path(r"~\PycharmProjects\gemini api").expanduser()
#       2 sys.path.append(str(PROJECT_ROOT))
#       4 hot_lap_file_path = "assets/MoTec/spa/Spa-ferrari_296_gt3-fastest_lap_glat-float.csv"
#
# NameError: name 'pathlib' is not defined
